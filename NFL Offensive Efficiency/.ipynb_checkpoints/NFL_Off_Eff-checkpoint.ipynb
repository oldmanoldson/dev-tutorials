# %%
base_url = "https://cdn.espn.com/core/nfl/"

# %%
r = requests.get(f"{base_url}schedule?xhr=1&year=2024&week=1")
result = r.json()

# %%
# Load the JSON file
data = result

# Parse the 'content' section to extract 'week', 'name', 'teamId', 'displayName', and 'href' with 'gameId'
parsed_data = []

# Iterate over the 'schedule' to gather the required fields
for date, details in data['content']['schedule'].items():
    for game in details['games']:
        week = game['week']['number']
        name = game['name']
        
        # Extract competitors and game links
        for competition in game['competitions']:
            for team in competition['competitors']:
                teamId = team['team']['id']
                displayName = team['team']['displayName']
                
                # Extract gameId from 'links' if available
                for link in game['links']:
                    if 'gameId=' in link['href']:
                        gameId = link['href'].split('gameId=')[1]
                        parsed_data.append({
                            'week': week,
                            'name': name,
                            'teamId': teamId,
                            'displayName': displayName,
                            'gameId': gameId
                        })

# %%
import requests
import json
import pandas as pd

# %%
#Function to pass year and week to ESPN API
def espn_nfl_sched(year, week):
    # Set base URL
    base_url = "https://cdn.espn.com/core/nfl/"

    # Make API GET request
    r = requests.get(f"{base_url}schedule?xhr=1&year={year}&week={week}")
    result = r.json()

    # Parse schedule data
    # Load the JSON file
    data = result
    
    # Iterate over the 'schedule' to gather the required fields
    for date, details in data['content']['schedule'].items():
        for game in details['games']:
            week = game['week']['number']
            name = game['name']
            
            # Extract competitors and game links
            for competition in game['competitions']:
                for team in competition['competitors']:
                    teamId = team['team']['id']
                    displayName = team['team']['displayName']
                    
                    # Extract gameId from 'links' if available
                    for link in game['links']:
                        if 'gameId=' in link['href']:
                            gameId = link['href'].split('gameId=')[1]
                            parsed_data.append({
                                'year': year,
                                'week': week,
                                'name': name,
                                'teamId': teamId,
                                'displayName': displayName,
                                'gameId': gameId
                            })

    return parsed_data

# %%
test = espn_nfl_sched("2024","1")
test

# %%
#iterate through current weeks of 2024 season
parsed_data = []
for i in range(1,5):
    season = espn_nfl_sched("2024",i)

# %%
season
# Out:
# [{'year': '2024',
#   'week': 1,
#   'name': 'Baltimore Ravens at Kansas City Chiefs',
#   'teamId': '12',
#   'displayName': 'Kansas City Chiefs',
#   'gameId': '401671789'},
#  {'year': '2024',
#   'week': 1,
#   'name': 'Baltimore Ravens at Kansas City Chiefs',
#   'teamId': '12',
#   'displayName': 'Kansas City Chiefs',
#   'gameId': '401671789'},
#  {'year': '2024',
#   'week': 1,
#   'name': 'Baltimore Ravens at Kansas City Chiefs',
#   'teamId': '33',
#   'displayName': 'Baltimore Ravens',
#   'gameId': '401671789'},
#  {'year': '2024',
#   'week': 1,
#   'name': 'Baltimore Ravens at Kansas City Chiefs',
#   'teamId': '33',
#   'displayName': 'Baltimore Ravens',
#   'gameId': '401671789'},
#  {'year': '2024',
#   'week': 1,
#   'name': 'Green Bay Packers at Philadelphia Eagles',
#   'teamId': '21',
#   'displayName': 'Philadelphia Eagles',
#   'gameId': '401671805'},
#  {'year': '2024',
#   'week': 1,
#   'name': 'Green Bay Packers at Philadelphia Eagles',
#   'teamId': '21',
#   'displayName': 'Philadelphia Eagles',
#   'gameId': '401671805'},
#  {'year': '2024',
#   'week': 1,
#   'name': 'Green Bay Packers at Philadelphia Eagles',
#   'teamId': '9',
#   'displayName': 'Green Bay Packers',
#   'gameId': '401671805'},
#  {'year': '2024',
#   'week': 1,
#   'name': 'Green Bay Packers at Philadelphia Eagles',
#   'teamId': '9',
#   'displayName': 'Green Bay Packers',
#   'gameId': '401671805'},
#  {'year': '2024',
#   'week': 1,
#   'name': 'Pittsburgh Steelers at Atlanta Falcons',
#   'teamId': '1',
#   'displayName': 'Atlanta Falcons',
#   'gameId': '401671744'},
#  {'year': '2024',
#   'week': 1,
#   'name': 'Pittsburgh Steelers at Atlanta Falcons',
#   'teamId': '1',
#   'displayName': 'Atlanta Falcons',
#   'gameId': '401671744'},
#  {'year': '2024',
#   'week': 1,
#   'name': 'Pittsburgh Steelers at Atlanta Falcons',
#   'teamId': '23',
#   'displayName': 'Pittsburgh Steelers',
#   'gameId': '401671744'},
#  {'year': '2024',
#   'week': 1,
#   'name': 'Pittsburgh Steelers at Atlanta Falcons',
#   'teamId': '23',
#   'displayName': 'Pittsburgh Steelers',
#   'gameId': '401671744'},
#  {'year': '2024',
#   'week': 1,
#   'name': 'Arizona Cardinals at Buffalo Bills',
#   'teamId': '2',
#   'displayName': 'Buffalo Bills',
#   'gameId': '401671617'},
#  {'year': '2024',
#   'week': 1,
#   'name': 'Arizona Cardinals at Buffalo Bills',
#   'teamId': '22',
#   'displayName': 'Arizona Cardinals',
#   'gameId': '401671617'},
#  {'year': '2024',
#   'week': 1,
#   'name': 'Tennessee Titans at Chicago Bears',
#   'teamId': '3',
#   'displayName': 'Chicago Bears',
#   'gameId': '401671719'},
#  {'year': '2024',
#   'week': 1,
#   'name': 'Tennessee Titans at Chicago Bears',
#   'teamId': '10',
#   'displayName': 'Tennessee Titans',
#   'gameId': '401671719'},
#  {'year': '2024',
#   'week': 1,
#   'name': 'New England Patriots at Cincinnati Bengals',
#   'teamId': '4',
#   'displayName': 'Cincinnati Bengals',
#   'gameId': '401671628'},
#  {'year': '2024',
#   'week': 1,
#   'name': 'New England Patriots at Cincinnati Bengals',
#   'teamId': '17',
#   'displayName': 'New England Patriots',
#   'gameId': '401671628'},
#  {'year': '2024',
#   'week': 1,
#   'name': 'Houston Texans at Indianapolis Colts',
#   'teamId': '11',
#   'displayName': 'Indianapolis Colts',
#   'gameId': '401671861'},
#  {'year': '2024',
#   'week': 1,
#   'name': 'Houston Texans at Indianapolis Colts',
#   'teamId': '34',
#   'displayName': 'Houston Texans',
#   'gameId': '401671861'},
#  {'year': '2024',
#   'week': 1,
#   'name': 'Jacksonville Jaguars at Miami Dolphins',
#   'teamId': '15',
#   'displayName': 'Miami Dolphins',
#   'gameId': '401671849'},
#  {'year': '2024',
#   'week': 1,
#   'name': 'Jacksonville Jaguars at Miami Dolphins',
#   'teamId': '30',
#   'displayName': 'Jacksonville Jaguars',
#   'gameId': '401671849'},
#  {'year': '2024',
#   'week': 1,
#   'name': 'Carolina Panthers at New Orleans Saints',
#   'teamId': '18',
#   'displayName': 'New Orleans Saints',
#   'gameId': '401671734'},
#  {'year': '2024',
#   'week': 1,
#   'name': 'Carolina Panthers at New Orleans Saints',
#   'teamId': '18',
#   'displayName': 'New Orleans Saints',
#   'gameId': '401671734'},
#  {'year': '2024',
#   'week': 1,
#   'name': 'Carolina Panthers at New Orleans Saints',
#   'teamId': '29',
#   'displayName': 'Carolina Panthers',
#   'gameId': '401671734'},
#  {'year': '2024',
#   'week': 1,
#   'name': 'Carolina Panthers at New Orleans Saints',
#   'teamId': '29',
#   'displayName': 'Carolina Panthers',
#   'gameId': '401671734'},
#  {'year': '2024',
#   'week': 1,
#   'name': 'Minnesota Vikings at New York Giants',
#   'teamId': '19',
#   'displayName': 'New York Giants',
#   'gameId': '401671712'},
#  {'year': '2024',
#   'week': 1,
#   'name': 'Minnesota Vikings at New York Giants',
#   'teamId': '19',
#   'displayName': 'New York Giants',
#   'gameId': '401671712'},
#  {'year': '2024',
#   'week': 1,
#   'name': 'Minnesota Vikings at New York Giants',
#   'teamId': '16',
#   'displayName': 'Minnesota Vikings',
#   'gameId': '401671712'},
#  {'year': '2024',
#   'week': 1,
#   'name': 'Minnesota Vikings at New York Giants',
#   'teamId': '16',
#   'displayName': 'Minnesota Vikings',
#   'gameId': '401671712'},
#  {'year': '2024',
#   'week': 1,
#   'name': 'Las Vegas Raiders at Los Angeles Chargers',
#   'teamId': '24',
#   'displayName': 'Los Angeles Chargers',
#   'gameId': '401671659'},
#  {'year': '2024',
#   'week': 1,
#   'name': 'Las Vegas Raiders at Los Angeles Chargers',
#   'teamId': '13',
#   'displayName': 'Las Vegas Raiders',
#   'gameId': '401671659'},
#  {'year': '2024',
#   'week': 1,
#   'name': 'Denver Broncos at Seattle Seahawks',
#   'teamId': '26',
#   'displayName': 'Seattle Seahawks',
#   'gameId': '401671664'},
#  {'year': '2024',
#   'week': 1,
#   'name': 'Denver Broncos at Seattle Seahawks',
#   'teamId': '7',
#   'displayName': 'Denver Broncos',
#   'gameId': '401671664'},
#  {'year': '2024',
#   'week': 1,
#   'name': 'Dallas Cowboys at Cleveland Browns',
#   'teamId': '5',
#   'displayName': 'Cleveland Browns',
#   'gameId': '401671761'},
#  {'year': '2024',
#   'week': 1,
#   'name': 'Dallas Cowboys at Cleveland Browns',
#   'teamId': '5',
#   'displayName': 'Cleveland Browns',
#   'gameId': '401671761'},
#  {'year': '2024',
#   'week': 1,
#   'name': 'Dallas Cowboys at Cleveland Browns',
#   'teamId': '6',
#   'displayName': 'Dallas Cowboys',
#   'gameId': '401671761'},
#  {'year': '2024',
#   'week': 1,
#   'name': 'Dallas Cowboys at Cleveland Browns',
#   'teamId': '6',
#   'displayName': 'Dallas Cowboys',
#   'gameId': '401671761'},
#  {'year': '2024',
#   'week': 1,
#   'name': 'Washington Commanders at Tampa Bay Buccaneers',
#   'teamId': '27',
#   'displayName': 'Tampa Bay Buccaneers',
#   'gameId': '401671770'},
#  {'year': '2024',
#   'week': 1,
#   'name': 'Washington Commanders at Tampa Bay Buccaneers',
#   'teamId': '28',
#   'displayName': 'Washington Commanders',
#   'gameId': '401671770'},
#  {'year': '2024',
#   'week': 1,
#   'name': 'Los Angeles Rams at Detroit Lions',
#   'teamId': '8',
#   'displayName': 'Detroit Lions',
#   'gameId': '401671792'},
#  {'year': '2024',
#   'week': 1,
#   'name': 'Los Angeles Rams at Detroit Lions',
#   'teamId': '14',
#   'displayName': 'Los Angeles Rams',
#   'gameId': '401671792'},
#  {'year': '2024',
#   'week': 1,
#   'name': 'New York Jets at San Francisco 49ers',
#   'teamId': '25',
#   'displayName': 'San Francisco 49ers',
#   'gameId': '401671696'},
#  {'year': '2024',
#   'week': 1,
#   'name': 'New York Jets at San Francisco 49ers',
#   'teamId': '25',
#   'displayName': 'San Francisco 49ers',
#   'gameId': '401671696'},
#  {'year': '2024',
#   'week': 1,
#   'name': 'New York Jets at San Francisco 49ers',
#   'teamId': '20',
#   'displayName': 'New York Jets',
#   'gameId': '401671696'},
#  {'year': '2024',
#   'week': 1,
#   'name': 'New York Jets at San Francisco 49ers',
#   'teamId': '20',
#   'displayName': 'New York Jets',
#   'gameId': '401671696'},
#  {'year': '2024',
#   'week': 2,
#   'name': 'Buffalo Bills at Miami Dolphins',
#   'teamId': '15',
#   'displayName': 'Miami Dolphins',
#   'gameId': '401671807'},
#  {'year': '2024',
#   'week': 2,
#   'name': 'Buffalo Bills at Miami Dolphins',
#   'teamId': '15',
#   'displayName': 'Miami Dolphins',
#   'gameId': '401671807'},
#  {'year': '2024',
#   'week': 2,
#   'name': 'Buffalo Bills at Miami Dolphins',
#   'teamId': '2',
#   'displayName': 'Buffalo Bills',
#   'gameId': '401671807'},
#  {'year': '2024',
#   'week': 2,
#   'name': 'Buffalo Bills at Miami Dolphins',
#   'teamId': '2',
#   'displayName': 'Buffalo Bills',
#   'gameId': '401671807'},
#  {'year': '2024',
#   'week': 2,
#   'name': 'New Orleans Saints at Dallas Cowboys',
#   'teamId': '6',
#   'displayName': 'Dallas Cowboys',
#   'gameId': '401671709'},
#  {'year': '2024',
#   'week': 2,
#   'name': 'New Orleans Saints at Dallas Cowboys',
#   'teamId': '18',
#   'displayName': 'New Orleans Saints',
#   'gameId': '401671709'},
#  {'year': '2024',
#   'week': 2,
#   'name': 'Tampa Bay Buccaneers at Detroit Lions',
#   'teamId': '8',
#   'displayName': 'Detroit Lions',
#   'gameId': '401671721'},
#  {'year': '2024',
#   'week': 2,
#   'name': 'Tampa Bay Buccaneers at Detroit Lions',
#   'teamId': '27',
#   'displayName': 'Tampa Bay Buccaneers',
#   'gameId': '401671721'},
#  {'year': '2024',
#   'week': 2,
#   'name': 'Indianapolis Colts at Green Bay Packers',
#   'teamId': '9',
#   'displayName': 'Green Bay Packers',
#   'gameId': '401671723'},
#  {'year': '2024',
#   'week': 2,
#   'name': 'Indianapolis Colts at Green Bay Packers',
#   'teamId': '11',
#   'displayName': 'Indianapolis Colts',
#   'gameId': '401671723'},
#  {'year': '2024',
#   'week': 2,
#   'name': 'New York Jets at Tennessee Titans',
#   'teamId': '10',
#   'displayName': 'Tennessee Titans',
#   'gameId': '401671636'},
#  {'year': '2024',
#   'week': 2,
#   'name': 'New York Jets at Tennessee Titans',
#   'teamId': '20',
#   'displayName': 'New York Jets',
#   'gameId': '401671636'},
#  {'year': '2024',
#   'week': 2,
#   'name': 'San Francisco 49ers at Minnesota Vikings',
#   'teamId': '16',
#   'displayName': 'Minnesota Vikings',
#   'gameId': '401671645'},
#  {'year': '2024',
#   'week': 2,
#   'name': 'San Francisco 49ers at Minnesota Vikings',
#   'teamId': '25',
#   'displayName': 'San Francisco 49ers',
#   'gameId': '401671645'},
#  {'year': '2024',
#   'week': 2,
#   'name': 'Seattle Seahawks at New England Patriots',
#   'teamId': '17',
#   'displayName': 'New England Patriots',
#   'gameId': '401671702'},
#  {'year': '2024',
#   'week': 2,
#   'name': 'Seattle Seahawks at New England Patriots',
#   'teamId': '26',
#   'displayName': 'Seattle Seahawks',
#   'gameId': '401671702'},
#  {'year': '2024',
#   'week': 2,
#   'name': 'New York Giants at Washington Commanders',
#   'teamId': '28',
#   'displayName': 'Washington Commanders',
#   'gameId': '401671716'},
#  {'year': '2024',
#   'week': 2,
#   'name': 'New York Giants at Washington Commanders',
#   'teamId': '19',
#   'displayName': 'New York Giants',
#   'gameId': '401671716'},
#  {'year': '2024',
#   'week': 2,
#   'name': 'Los Angeles Chargers at Carolina Panthers',
#   'teamId': '29',
#   'displayName': 'Carolina Panthers',
#   'gameId': '401671652'},
#  {'year': '2024',
#   'week': 2,
#   'name': 'Los Angeles Chargers at Carolina Panthers',
#   'teamId': '24',
#   'displayName': 'Los Angeles Chargers',
#   'gameId': '401671652'},
#  {'year': '2024',
#   'week': 2,
#   'name': 'Cleveland Browns at Jacksonville Jaguars',
#   'teamId': '30',
#   'displayName': 'Jacksonville Jaguars',
#   'gameId': '401671635'},
#  {'year': '2024',
#   'week': 2,
#   'name': 'Cleveland Browns at Jacksonville Jaguars',
#   'teamId': '5',
#   'displayName': 'Cleveland Browns',
#   'gameId': '401671635'},
#  {'year': '2024',
#   'week': 2,
#   'name': 'Las Vegas Raiders at Baltimore Ravens',
#   'teamId': '33',
#   'displayName': 'Baltimore Ravens',
#   'gameId': '401671624'},
#  {'year': '2024',
#   'week': 2,
#   'name': 'Las Vegas Raiders at Baltimore Ravens',
#   'teamId': '13',
#   'displayName': 'Las Vegas Raiders',
#   'gameId': '401671624'},
#  {'year': '2024',
#   'week': 2,
#   'name': 'Los Angeles Rams at Arizona Cardinals',
#   'teamId': '22',
#   'displayName': 'Arizona Cardinals',
#   'gameId': '401671754'},
#  {'year': '2024',
#   'week': 2,
#   'name': 'Los Angeles Rams at Arizona Cardinals',
#   'teamId': '14',
#   'displayName': 'Los Angeles Rams',
#   'gameId': '401671754'},
#  {'year': '2024',
#   'week': 2,
#   'name': 'Pittsburgh Steelers at Denver Broncos',
#   'teamId': '7',
#   'displayName': 'Denver Broncos',
#   'gameId': '401671668'},
#  {'year': '2024',
#   'week': 2,
#   'name': 'Pittsburgh Steelers at Denver Broncos',
#   'teamId': '23',
#   'displayName': 'Pittsburgh Steelers',
#   'gameId': '401671668'},
#  {'year': '2024',
#   'week': 2,
#   'name': 'Cincinnati Bengals at Kansas City Chiefs',
#   'teamId': '12',
#   'displayName': 'Kansas City Chiefs',
#   'gameId': '401671670'},
#  {'year': '2024',
#   'week': 2,
#   'name': 'Cincinnati Bengals at Kansas City Chiefs',
#   'teamId': '4',
#   'displayName': 'Cincinnati Bengals',
#   'gameId': '401671670'},
#  {'year': '2024',
#   'week': 2,
#   'name': 'Chicago Bears at Houston Texans',
#   'teamId': '34',
#   'displayName': 'Houston Texans',
#   'gameId': '401671786'},
#  {'year': '2024',
#   'week': 2,
#   'name': 'Chicago Bears at Houston Texans',
#   'teamId': '3',
#   'displayName': 'Chicago Bears',
#   'gameId': '401671786'},
#  {'year': '2024',
#   'week': 2,
#   'name': 'Atlanta Falcons at Philadelphia Eagles',
#   'teamId': '21',
#   'displayName': 'Philadelphia Eagles',
#   'gameId': '401671691'},
#  {'year': '2024',
#   'week': 2,
#   'name': 'Atlanta Falcons at Philadelphia Eagles',
#   'teamId': '21',
#   'displayName': 'Philadelphia Eagles',
#   'gameId': '401671691'},
#  {'year': '2024',
#   'week': 2,
#   'name': 'Atlanta Falcons at Philadelphia Eagles',
#   'teamId': '1',
#   'displayName': 'Atlanta Falcons',
#   'gameId': '401671691'},
#  {'year': '2024',
#   'week': 2,
#   'name': 'Atlanta Falcons at Philadelphia Eagles',
#   'teamId': '1',
#   'displayName': 'Atlanta Falcons',
#   'gameId': '401671691'},
#  {'year': '2024',
#   'week': 3,
#   'name': 'New England Patriots at New York Jets',
#   'teamId': '20',
#   'displayName': 'New York Jets',
#   'gameId': '401671808'},
#  {'year': '2024',
#   'week': 3,
#   'name': 'New England Patriots at New York Jets',
#   'teamId': '20',
#   'displayName': 'New York Jets',
#   'gameId': '401671808'},
#  {'year': '2024',
#   'week': 3,
#   'name': 'New England Patriots at New York Jets',
#   'teamId': '17',
#   'displayName': 'New England Patriots',
#   'gameId': '401671808'},
#  {'year': '2024',
#   'week': 3,
#   'name': 'New England Patriots at New York Jets',
#   'teamId': '17',
#   'displayName': 'New England Patriots',
#   'gameId': '401671808'},
#  {'year': '2024',
#   'week': 3,
#   'name': 'New York Giants at Cleveland Browns',
#   'teamId': '5',
#   'displayName': 'Cleveland Browns',
#   'gameId': '401671855'},
#  {'year': '2024',
#   'week': 3,
#   'name': 'New York Giants at Cleveland Browns',
#   'teamId': '19',
#   'displayName': 'New York Giants',
#   'gameId': '401671855'},
#  {'year': '2024',
#   'week': 3,
#   'name': 'Green Bay Packers at Tennessee Titans',
#   'teamId': '10',
#   'displayName': 'Tennessee Titans',
#   'gameId': '401671823'},
#  {'year': '2024',
#   'week': 3,
#   'name': 'Green Bay Packers at Tennessee Titans',
#   'teamId': '9',
#   'displayName': 'Green Bay Packers',
#   'gameId': '401671823'},
#  {'year': '2024',
#   'week': 3,
#   'name': 'Chicago Bears at Indianapolis Colts',
#   'teamId': '11',
#   'displayName': 'Indianapolis Colts',
#   'gameId': '401671865'},
#  {'year': '2024',
#   'week': 3,
#   'name': 'Chicago Bears at Indianapolis Colts',
#   'teamId': '3',
#   'displayName': 'Chicago Bears',
#   'gameId': '401671865'},
#  {'year': '2024',
#   'week': 3,
#   'name': 'Houston Texans at Minnesota Vikings',
#   'teamId': '16',
#   'displayName': 'Minnesota Vikings',
#   'gameId': '401671646'},
#  {'year': '2024',
#   'week': 3,
#   'name': 'Houston Texans at Minnesota Vikings',
#   'teamId': '34',
#   'displayName': 'Houston Texans',
#   'gameId': '401671646'},
#  {'year': '2024',
#   'week': 3,
#   'name': 'Philadelphia Eagles at New Orleans Saints',
#   'teamId': '18',
#   'displayName': 'New Orleans Saints',
#   'gameId': '401671736'},
#  {'year': '2024',
#   'week': 3,
#   'name': 'Philadelphia Eagles at New Orleans Saints',
#   'teamId': '21',
#   'displayName': 'Philadelphia Eagles',
#   'gameId': '401671736'},
#  {'year': '2024',
#   'week': 3,
#   'name': 'Los Angeles Chargers at Pittsburgh Steelers',
#   'teamId': '23',
#   'displayName': 'Pittsburgh Steelers',
#   'gameId': '401671632'},
#  {'year': '2024',
#   'week': 3,
#   'name': 'Los Angeles Chargers at Pittsburgh Steelers',
#   'teamId': '23',
#   'displayName': 'Pittsburgh Steelers',
#   'gameId': '401671632'},
#  {'year': '2024',
#   'week': 3,
#   'name': 'Los Angeles Chargers at Pittsburgh Steelers',
#   'teamId': '24',
#   'displayName': 'Los Angeles Chargers',
#   'gameId': '401671632'},
#  {'year': '2024',
#   'week': 3,
#   'name': 'Los Angeles Chargers at Pittsburgh Steelers',
#   'teamId': '24',
#   'displayName': 'Los Angeles Chargers',
#   'gameId': '401671632'},
#  {'year': '2024',
#   'week': 3,
#   'name': 'Denver Broncos at Tampa Bay Buccaneers',
#   'teamId': '27',
#   'displayName': 'Tampa Bay Buccaneers',
#   'gameId': '401671741'},
#  {'year': '2024',
#   'week': 3,
#   'name': 'Denver Broncos at Tampa Bay Buccaneers',
#   'teamId': '7',
#   'displayName': 'Denver Broncos',
#   'gameId': '401671741'},
#  {'year': '2024',
#   'week': 3,
#   'name': 'Carolina Panthers at Las Vegas Raiders',
#   'teamId': '13',
#   'displayName': 'Las Vegas Raiders',
#   'gameId': '401671658'},
#  {'year': '2024',
#   'week': 3,
#   'name': 'Carolina Panthers at Las Vegas Raiders',
#   'teamId': '29',
#   'displayName': 'Carolina Panthers',
#   'gameId': '401671658'},
#  {'year': '2024',
#   'week': 3,
#   'name': 'Miami Dolphins at Seattle Seahawks',
#   'teamId': '26',
#   'displayName': 'Seattle Seahawks',
#   'gameId': '401671662'},
#  {'year': '2024',
#   'week': 3,
#   'name': 'Miami Dolphins at Seattle Seahawks',
#   'teamId': '15',
#   'displayName': 'Miami Dolphins',
#   'gameId': '401671662'},
#  {'year': '2024',
#   'week': 3,
#   'name': 'Baltimore Ravens at Dallas Cowboys',
#   'teamId': '6',
#   'displayName': 'Dallas Cowboys',
#   'gameId': '401671763'},
#  {'year': '2024',
#   'week': 3,
#   'name': 'Baltimore Ravens at Dallas Cowboys',
#   'teamId': '6',
#   'displayName': 'Dallas Cowboys',
#   'gameId': '401671763'},
#  {'year': '2024',
#   'week': 3,
#   'name': 'Baltimore Ravens at Dallas Cowboys',
#   'teamId': '33',
#   'displayName': 'Baltimore Ravens',
#   'gameId': '401671763'},
#  {'year': '2024',
#   'week': 3,
#   'name': 'Baltimore Ravens at Dallas Cowboys',
#   'teamId': '33',
#   'displayName': 'Baltimore Ravens',
#   'gameId': '401671763'},
#  {'year': '2024',
#   'week': 3,
#   'name': 'San Francisco 49ers at Los Angeles Rams',
#   'teamId': '14',
#   'displayName': 'Los Angeles Rams',
#   'gameId': '401671772'},
#  {'year': '2024',
#   'week': 3,
#   'name': 'San Francisco 49ers at Los Angeles Rams',
#   'teamId': '25',
#   'displayName': 'San Francisco 49ers',
#   'gameId': '401671772'},
#  {'year': '2024',
#   'week': 3,
#   'name': 'Detroit Lions at Arizona Cardinals',
#   'teamId': '22',
#   'displayName': 'Arizona Cardinals',
#   'gameId': '401671771'},
#  {'year': '2024',
#   'week': 3,
#   'name': 'Detroit Lions at Arizona Cardinals',
#   'teamId': '8',
#   'displayName': 'Detroit Lions',
#   'gameId': '401671771'},
#  {'year': '2024',
#   'week': 3,
#   'name': 'Kansas City Chiefs at Atlanta Falcons',
#   'teamId': '1',
#   'displayName': 'Atlanta Falcons',
#   'gameId': '401671793'},
#  {'year': '2024',
#   'week': 3,
#   'name': 'Kansas City Chiefs at Atlanta Falcons',
#   'teamId': '12',
#   'displayName': 'Kansas City Chiefs',
#   'gameId': '401671793'},
#  {'year': '2024',
#   'week': 3,
#   'name': 'Jacksonville Jaguars at Buffalo Bills',
#   'teamId': '2',
#   'displayName': 'Buffalo Bills',
#   'gameId': '401671682'},
#  {'year': '2024',
#   'week': 3,
#   'name': 'Jacksonville Jaguars at Buffalo Bills',
#   'teamId': '2',
#   'displayName': 'Buffalo Bills',
#   'gameId': '401671682'},
#  {'year': '2024',
#   'week': 3,
#   'name': 'Jacksonville Jaguars at Buffalo Bills',
#   'teamId': '30',
#   'displayName': 'Jacksonville Jaguars',
#   'gameId': '401671682'},
#  {'year': '2024',
#   'week': 3,
#   'name': 'Jacksonville Jaguars at Buffalo Bills',
#   'teamId': '30',
#   'displayName': 'Jacksonville Jaguars',
#   'gameId': '401671682'},
#  {'year': '2024',
#   'week': 3,
#   'name': 'Washington Commanders at Cincinnati Bengals',
#   'teamId': '4',
#   'displayName': 'Cincinnati Bengals',
#   'gameId': '401671490'},
#  {'year': '2024',
#   'week': 3,
#   'name': 'Washington Commanders at Cincinnati Bengals',
#   'teamId': '4',
#   'displayName': 'Cincinnati Bengals',
#   'gameId': '401671490'},
#  {'year': '2024',
#   'week': 3,
#   'name': 'Washington Commanders at Cincinnati Bengals',
#   'teamId': '28',
#   'displayName': 'Washington Commanders',
#   'gameId': '401671490'},
#  {'year': '2024',
#   'week': 3,
#   'name': 'Washington Commanders at Cincinnati Bengals',
#   'teamId': '28',
#   'displayName': 'Washington Commanders',
#   'gameId': '401671490'},
#  {'year': '2024',
#   'week': 4,
#   'name': 'Dallas Cowboys at New York Giants',
#   'teamId': '19',
#   'displayName': 'New York Giants',
#   'gameId': '401671812'},
#  {'year': '2024',
#   'week': 4,
#   'name': 'Dallas Cowboys at New York Giants',
#   'teamId': '19',
#   'displayName': 'New York Giants',
#   'gameId': '401671812'},
#  {'year': '2024',
#   'week': 4,
#   'name': 'Dallas Cowboys at New York Giants',
#   'teamId': '6',
#   'displayName': 'Dallas Cowboys',
#   'gameId': '401671812'},
#  {'year': '2024',
#   'week': 4,
#   'name': 'Dallas Cowboys at New York Giants',
#   'teamId': '6',
#   'displayName': 'Dallas Cowboys',
#   'gameId': '401671812'},
#  {'year': '2024',
#   'week': 4,
#   'name': 'New Orleans Saints at Atlanta Falcons',
#   'teamId': '1',
#   'displayName': 'Atlanta Falcons',
#   'gameId': '401671727'},
#  {'year': '2024',
#   'week': 4,
#   'name': 'New Orleans Saints at Atlanta Falcons',
#   'teamId': '18',
#   'displayName': 'New Orleans Saints',
#   'gameId': '401671727'},
#  {'year': '2024',
#   'week': 4,
#   'name': 'Los Angeles Rams at Chicago Bears',
#   'teamId': '3',
#   'displayName': 'Chicago Bears',
#   'gameId': '401671871'},
#  {'year': '2024',
#   'week': 4,
#   'name': 'Los Angeles Rams at Chicago Bears',
#   'teamId': '14',
#   'displayName': 'Los Angeles Rams',
#   'gameId': '401671871'},
#  {'year': '2024',
#   'week': 4,
#   'name': 'Minnesota Vikings at Green Bay Packers',
#   'teamId': '9',
#   'displayName': 'Green Bay Packers',
#   'gameId': '401671643'},
#  {'year': '2024',
#   'week': 4,
#   'name': 'Minnesota Vikings at Green Bay Packers',
#   'teamId': '16',
#   'displayName': 'Minnesota Vikings',
#   'gameId': '401671643'},
#  {'year': '2024',
#   'week': 4,
#   'name': 'Pittsburgh Steelers at Indianapolis Colts',
#   'teamId': '11',
#   'displayName': 'Indianapolis Colts',
#   'gameId': '401671867'},
#  {'year': '2024',
#   'week': 4,
#   'name': 'Pittsburgh Steelers at Indianapolis Colts',
#   'teamId': '11',
#   'displayName': 'Indianapolis Colts',
#   'gameId': '401671867'},
#  {'year': '2024',
#   'week': 4,
#   'name': 'Pittsburgh Steelers at Indianapolis Colts',
#   'teamId': '23',
#   'displayName': 'Pittsburgh Steelers',
#   'gameId': '401671867'},
#  {'year': '2024',
#   'week': 4,
#   'name': 'Pittsburgh Steelers at Indianapolis Colts',
#   'teamId': '23',
#   'displayName': 'Pittsburgh Steelers',
#   'gameId': '401671867'},
#  {'year': '2024',
#   'week': 4,
#   'name': 'Denver Broncos at New York Jets',
#   'teamId': '20',
#   'displayName': 'New York Jets',
#   'gameId': '401671622'},
#  {'year': '2024',
#   'week': 4,
#   'name': 'Denver Broncos at New York Jets',
#   'teamId': '7',
#   'displayName': 'Denver Broncos',
#   'gameId': '401671622'},
#  {'year': '2024',
#   'week': 4,
#   'name': 'Philadelphia Eagles at Tampa Bay Buccaneers',
#   'teamId': '27',
#   'displayName': 'Tampa Bay Buccaneers',
#   'gameId': '401671740'},
#  {'year': '2024',
#   'week': 4,
#   'name': 'Philadelphia Eagles at Tampa Bay Buccaneers',
#   'teamId': '27',
#   'displayName': 'Tampa Bay Buccaneers',
#   'gameId': '401671740'},
#  {'year': '2024',
#   'week': 4,
#   'name': 'Philadelphia Eagles at Tampa Bay Buccaneers',
#   'teamId': '21',
#   'displayName': 'Philadelphia Eagles',
#   'gameId': '401671740'},
#  {'year': '2024',
#   'week': 4,
#   'name': 'Philadelphia Eagles at Tampa Bay Buccaneers',
#   'teamId': '21',
#   'displayName': 'Philadelphia Eagles',
#   'gameId': '401671740'},
#  {'year': '2024',
#   'week': 4,
#   'name': 'Cincinnati Bengals at Carolina Panthers',
#   'teamId': '29',
#   'displayName': 'Carolina Panthers',
#   'gameId': '401671745'},
#  {'year': '2024',
#   'week': 4,
#   'name': 'Cincinnati Bengals at Carolina Panthers',
#   'teamId': '4',
#   'displayName': 'Cincinnati Bengals',
#   'gameId': '401671745'},
#  {'year': '2024',
#   'week': 4,
#   'name': 'Jacksonville Jaguars at Houston Texans',
#   'teamId': '34',
#   'displayName': 'Houston Texans',
#   'gameId': '401671857'},
#  {'year': '2024',
#   'week': 4,
#   'name': 'Jacksonville Jaguars at Houston Texans',
#   'teamId': '30',
#   'displayName': 'Jacksonville Jaguars',
#   'gameId': '401671857'},
#  {'year': '2024',
#   'week': 4,
#   'name': 'Washington Commanders at Arizona Cardinals',
#   'teamId': '22',
#   'displayName': 'Arizona Cardinals',
#   'gameId': '401671755'},
#  {'year': '2024',
#   'week': 4,
#   'name': 'Washington Commanders at Arizona Cardinals',
#   'teamId': '28',
#   'displayName': 'Washington Commanders',
#   'gameId': '401671755'},
#  {'year': '2024',
#   'week': 4,
#   'name': 'New England Patriots at San Francisco 49ers',
#   'teamId': '25',
#   'displayName': 'San Francisco 49ers',
#   'gameId': '401671758'},
#  {'year': '2024',
#   'week': 4,
#   'name': 'New England Patriots at San Francisco 49ers',
#   'teamId': '17',
#   'displayName': 'New England Patriots',
#   'gameId': '401671758'},
#  {'year': '2024',
#   'week': 4,
#   'name': 'Cleveland Browns at Las Vegas Raiders',
#   'teamId': '13',
#   'displayName': 'Las Vegas Raiders',
#   'gameId': '401671672'},
#  {'year': '2024',
#   'week': 4,
#   'name': 'Cleveland Browns at Las Vegas Raiders',
#   'teamId': '5',
#   'displayName': 'Cleveland Browns',
#   'gameId': '401671672'},
#  {'year': '2024',
#   'week': 4,
#   'name': 'Kansas City Chiefs at Los Angeles Chargers',
#   'teamId': '24',
#   'displayName': 'Los Angeles Chargers',
#   'gameId': '401671674'},
#  {'year': '2024',
#   'week': 4,
#   'name': 'Kansas City Chiefs at Los Angeles Chargers',
#   'teamId': '12',
#   'displayName': 'Kansas City Chiefs',
#   'gameId': '401671674'},
#  {'year': '2024',
#   'week': 4,
#   'name': 'Buffalo Bills at Baltimore Ravens',
#   'teamId': '33',
#   'displayName': 'Baltimore Ravens',
#   'gameId': '401671783'},
#  {'year': '2024',
#   'week': 4,
#   'name': 'Buffalo Bills at Baltimore Ravens',
#   'teamId': '33',
#   'displayName': 'Baltimore Ravens',
#   'gameId': '401671783'},
#  {'year': '2024',
#   'week': 4,
#   'name': 'Buffalo Bills at Baltimore Ravens',
#   'teamId': '2',
#   'displayName': 'Buffalo Bills',
#   'gameId': '401671783'},
#  {'year': '2024',
#   'week': 4,
#   'name': 'Buffalo Bills at Baltimore Ravens',
#   'teamId': '2',
#   'displayName': 'Buffalo Bills',
#   'gameId': '401671783'},
#  {'year': '2024',
#   'week': 4,
#   'name': 'Tennessee Titans at Miami Dolphins',
#   'teamId': '15',
#   'displayName': 'Miami Dolphins',
#   'gameId': '401671683'},
#  {'year': '2024',
#   'week': 4,
#   'name': 'Tennessee Titans at Miami Dolphins',
#   'teamId': '15',
#   'displayName': 'Miami Dolphins',
#   'gameId': '401671683'},
#  {'year': '2024',
#   'week': 4,
#   'name': 'Tennessee Titans at Miami Dolphins',
#   'teamId': '10',
#   'displayName': 'Tennessee Titans',
#   'gameId': '401671683'},
#  {'year': '2024',
#   'week': 4,
#   'name': 'Tennessee Titans at Miami Dolphins',
#   'teamId': '10',
#   'displayName': 'Tennessee Titans',
#   'gameId': '401671683'},
#  {'year': '2024',
#   'week': 4,
#   'name': 'Seattle Seahawks at Detroit Lions',
#   'teamId': '8',
#   'displayName': 'Detroit Lions',
#   'gameId': '401671491'},
#  {'year': '2024',
#   'week': 4,
#   'name': 'Seattle Seahawks at Detroit Lions',
#   'teamId': '8',
#   'displayName': 'Detroit Lions',
#   'gameId': '401671491'},
#  {'year': '2024',
#   'week': 4,
#   'name': 'Seattle Seahawks at Detroit Lions',
#   'teamId': '26',
#   'displayName': 'Seattle Seahawks',
#   'gameId': '401671491'},
#  {'year': '2024',
#   'week': 4,
#   'name': 'Seattle Seahawks at Detroit Lions',
#   'teamId': '26',
#   'displayName': 'Seattle Seahawks',
#   'gameId': '401671491'}]

# %%
schedDF = pd.json_normalize(season)
schedDF = schedDF.drop_duplicates()
schedDF
# Out:
#      year  week                                      name teamId  \
# 0    2024     1    Baltimore Ravens at Kansas City Chiefs     12
# 2    2024     1    Baltimore Ravens at Kansas City Chiefs     33
# 4    2024     1  Green Bay Packers at Philadelphia Eagles     21
# 6    2024     1  Green Bay Packers at Philadelphia Eagles      9
# 8    2024     1    Pittsburgh Steelers at Atlanta Falcons      1
# ..    ...   ...                                       ...    ...
# 158  2024     4         Buffalo Bills at Baltimore Ravens      2
# 160  2024     4        Tennessee Titans at Miami Dolphins     15
# 162  2024     4        Tennessee Titans at Miami Dolphins     10
# 164  2024     4         Seattle Seahawks at Detroit Lions      8
# 166  2024     4         Seattle Seahawks at Detroit Lions     26
#
#              displayName     gameId
# 0     Kansas City Chiefs  401671789
# 2       Baltimore Ravens  401671789
# 4    Philadelphia Eagles  401671805
# 6      Green Bay Packers  401671805
# 8        Atlanta Falcons  401671744
# ..                   ...        ...
# 158        Buffalo Bills  401671783
# 160       Miami Dolphins  401671683
# 162     Tennessee Titans  401671683
# 164        Detroit Lions  401671491
# 166     Seattle Seahawks  401671491
#
# [128 rows x 6 columns]
