# %%
import requests
import json
import pandas as pd

# %%
#Function to pass year and week to ESPN API
def espn_nfl_sched(year, week):
    # Set base URL
    base_url = "https://cdn.espn.com/core/nfl/"

    # Make API GET request
    r = requests.get(f"{base_url}schedule?xhr=1&year={year}&week={week}")
    result = r.json()

    # Parse schedule data
    # Load the JSON file
    data = result
    
    # Iterate over the 'schedule' to gather the required fields
    for date, details in data['content']['schedule'].items():
        for game in details['games']:
            week = game['week']['number']
            name = game['name']
            
            # Extract competitors and game links
            for competition in game['competitions']:
                for team in competition['competitors']:
                    teamId = team['team']['id']
                    displayName = team['team']['displayName']
                    teamscore = team['score']
                    
                    # Extract gameId from 'links' if available
                    for link in game['links']:
                        if 'gameId=' in link['href']:
                            gameId = link['href'].split('gameId=')[1]
                            parsed_data.append({
                                'year': year,
                                'week': week,
                                'name': name,
                                'teamId': teamId,
                                'displayName': displayName,
                                'gameId': gameId,
                                'teamScore': teamscore
                            })

    return parsed_data

# %%
def game_boxscore(gameId):
    #pull game data
    game_url = f"https://cdn.espn.com/core/nfl/boxscore?xhr=1&gameId={gameId}"

    g = requests.get(game_url)
    game = g.json()
    data = game['gamepackageJSON']['boxscore']

    # Extracting data from the teams and their statistics
    for team_info in data['teams']:
        team = team_info['team']['displayName']
        home_away = team_info['homeAway']
        # Create a dictionary for each team and fill it with statistics
        team_stats = {
            'team': team,
            'homeAway': home_away
        }
        for stat in team_info['statistics']:
            stat_name = stat['name']
            stat_value = stat['displayValue']
            team_stats[stat_name] = stat_value
            team_stats['gameID'] = gameId
        
        teams_data.append(team_stats)

    return teams_data

# %%
#iterate through current weeks of 2024 season
parsed_data = []
for i in range(1,7):
    season = espn_nfl_sched("2024",i)

# %%
schedDF = pd.json_normalize(season)
schedDF = schedDF.drop_duplicates()
schedDF['tabkey'] = schedDF['displayName']+schedDF['gameId']
schedDF
# Out:
#      year  week                                      name teamId  \
# 0    2024     1    Baltimore Ravens at Kansas City Chiefs     12
# 2    2024     1    Baltimore Ravens at Kansas City Chiefs     33
# 4    2024     1  Green Bay Packers at Philadelphia Eagles     21
# 5    2024     1  Green Bay Packers at Philadelphia Eagles      9
# 6    2024     1    Pittsburgh Steelers at Atlanta Falcons      1
# ..    ...   ...                                       ...    ...
# 215  2024     6      Atlanta Falcons at Carolina Panthers      1
# 216  2024     6     Cincinnati Bengals at New York Giants     19
# 217  2024     6     Cincinnati Bengals at New York Giants      4
# 218  2024     6            Buffalo Bills at New York Jets     20
# 220  2024     6            Buffalo Bills at New York Jets      2
#
#              displayName     gameId teamScore                        tabkey
# 0     Kansas City Chiefs  401671789        27   Kansas City Chiefs401671789
# 2       Baltimore Ravens  401671789        20     Baltimore Ravens401671789
# 4    Philadelphia Eagles  401671805        34  Philadelphia Eagles401671805
# 5      Green Bay Packers  401671805        29    Green Bay Packers401671805
# 6        Atlanta Falcons  401671744        10      Atlanta Falcons401671744
# ..                   ...        ...       ...                           ...
# 215      Atlanta Falcons  401671769        38      Atlanta Falcons401671769
# 216      New York Giants  401671791         7      New York Giants401671791
# 217   Cincinnati Bengals  401671791        17   Cincinnati Bengals401671791
# 218        New York Jets  401671684        20        New York Jets401671684
# 220        Buffalo Bills  401671684        23        Buffalo Bills401671684
#
# [184 rows x 8 columns]

# %%
gameIds = schedDF['gameId'].unique().tolist()

# %%
teams_data = []
for j in gameIds:
    game_stats = game_boxscore(j)

# %%
# Convert to DataFrame
gameDF = pd.DataFrame(game_stats)
gameDF
# Out:
#                     team homeAway firstDowns     gameID firstDownsPassing  \
# 0       Baltimore Ravens     away         25  401671789                11
# 1     Kansas City Chiefs     home         21  401671789                15
# 2      Green Bay Packers     away         19  401671805                 9
# 3    Philadelphia Eagles     home         25  401671805                14
# 4    Pittsburgh Steelers     away         16  401671744                 6
# ..                   ...      ...        ...        ...               ...
# 179    Carolina Panthers     home         21  401671769                12
# 180   Cincinnati Bengals     away         13  401671791                10
# 181      New York Giants     home         24  401671791                10
# 182        Buffalo Bills     away         24  401671684                10
# 183        New York Jets     home         20  401671684                12
#
#     firstDownsRushing firstDownsPenalty thirdDownEff fourthDownEff  \
# 0                  13                 1         7-14           1-2
# 1                   4                 2          4-9           0-0
# 2                   7                 3         3-11           1-1
# 3                   8                 3         4-14           1-1
# 4                   9                 1         8-17           0-1
# ..                ...               ...          ...           ...
# 179                 8                 1         5-11           0-1
# 180                 3                 0         4-11           0-0
# 181                11                 3         5-15           3-5
# 182                10                 4         5-11           0-0
# 183                 5                 3         4-12           0-0
#
#     totalOffensivePlays  ... sacksYardsLost rushingYards rushingAttempts  \
# 0                    74  ...            1-6          185              32
# 1                    50  ...           2-10           72              20
# 2                    58  ...            2-9          163              21
# 3                    74  ...           2-12          144              38
# 4                    66  ...           2-23          137              41
# ..                  ...  ...            ...          ...             ...
# 179                  62  ...            0-0          114              24
# 180                  52  ...           4-25          121              20
# 181                  74  ...           2-15          119              31
# 182                  60  ...            2-5          149              33
# 183                  59  ...           3-22          121              21
#
#     yardsPerRushAttempt redZoneAttempts totalPenaltiesYards turnovers  \
# 0                   5.8             1-4                7-64         1
# 1                   3.6             1-3                6-45         1
# 2                   7.8             1-4               10-71         1
# 3                   3.8             3-6                7-57         3
# 4                   3.3             0-2                9-60         0
# ..                  ...             ...                 ...       ...
# 179                 4.8             2-3               10-74         2
# 180                 6.1             0-1                6-67         1
# 181                 3.8             1-2                 2-9         1
# 182                 4.5             3-4               11-94         0
# 183                 5.8             1-4              11-110         1
#
#     fumblesLost defensiveTouchdowns possessionTime
# 0             1                   0          33:43
# 1             0                   0          26:17
# 2             0                   0          27:13
# 3             1                   0          32:47
# 4             0                   0          35:36
# ..          ...                 ...            ...
# 179           0                   0          29:20
# 180           1                   0          25:53
# 181           0                   0          34:07
# 182           0                   0          29:34
# 183           0                   0          30:26
#
# [184 rows x 27 columns]

# %%
for col in gameDF.columns:
    print(col)
# Out:
# team
# homeAway
# firstDowns
# gameID
# firstDownsPassing
# firstDownsRushing
# firstDownsPenalty
# thirdDownEff
# fourthDownEff
# totalOffensivePlays
# totalYards
# yardsPerPlay
# totalDrives
# netPassingYards
# completionAttempts
# yardsPerPass
# interceptions
# sacksYardsLost
# rushingYards
# rushingAttempts
# yardsPerRushAttempt
# redZoneAttempts
# totalPenaltiesYards
# turnovers
# fumblesLost
# defensiveTouchdowns
# possessionTime

# %%
parsedGameDF = gameDF[['team', 'gameID', 'totalYards', 'netPassingYards', 'sacksYardsLost', 'rushingYards', 'defensiveTouchdowns']]
parsedGameDF['tabkey'] = parsedGameDF['team']+parsedGameDF['gameID']
parsedGameDF
# Out:
# /tmp/ipykernel_1364/2671073685.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   parsedGameDF['tabkey'] = parsedGameDF['team']+parsedGameDF['gameID']
#                     team     gameID totalYards netPassingYards sacksYardsLost  \
# 0       Baltimore Ravens  401671789        452             267            1-6
# 1     Kansas City Chiefs  401671789        353             281           2-10
# 2      Green Bay Packers  401671805        414             251            2-9
# 3    Philadelphia Eagles  401671805        410             266           2-12
# 4    Pittsburgh Steelers  401671744        270             133           2-23
# ..                   ...        ...        ...             ...            ...
# 179    Carolina Panthers  401671769        335             221            0-0
# 180   Cincinnati Bengals  401671791        304             183           4-25
# 181      New York Giants  401671791        309             190           2-15
# 182        Buffalo Bills  401671684        359             210            2-5
# 183        New York Jets  401671684        393             272           3-22
#
#     rushingYards defensiveTouchdowns                        tabkey
# 0            185                   0     Baltimore Ravens401671789
# 1             72                   0   Kansas City Chiefs401671789
# 2            163                   0    Green Bay Packers401671805
# 3            144                   0  Philadelphia Eagles401671805
# 4            137                   0  Pittsburgh Steelers401671744
# ..           ...                 ...                           ...
# 179          114                   0    Carolina Panthers401671769
# 180          121                   0   Cincinnati Bengals401671791
# 181          119                   0      New York Giants401671791
# 182          149                   0        Buffalo Bills401671684
# 183          121                   0        New York Jets401671684
#
# [184 rows x 8 columns]

# %%
df = gameDF.merge(parsedGameDF, on='tabkey')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_1364/3520935240.py in ?()
# ----> 1 df = gameDF.merge(parsedGameDF, on='tabkey')
#
# /usr/local/lib/python3.12/site-packages/pandas/core/frame.py in ?(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#   10828         validate: MergeValidate | None = None,
#   10829     ) -> DataFrame:
#   10830         from pandas.core.reshape.merge import merge
#   10831
# > 10832         return merge(
#   10833             self,
#   10834             right,
#   10835             how=how,
#
# /usr/local/lib/python3.12/site-packages/pandas/core/reshape/merge.py in ?(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     166             validate=validate,
#     167             copy=copy,
#     168         )
#     169     else:
# --> 170         op = _MergeOperation(
#     171             left_df,
#     172             right_df,
#     173             how=how,
#
# /usr/local/lib/python3.12/site-packages/pandas/core/reshape/merge.py in ?(self, left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, indicator, validate)
#     790             self.right_join_keys,
#     791             self.join_names,
#     792             left_drop,
#     793             right_drop,
# --> 794         ) = self._get_merge_keys()
#     795
#     796         if left_drop:
#     797             self.left = self.left._drop_labels_or_levels(left_drop)
#
# /usr/local/lib/python3.12/site-packages/pandas/core/reshape/merge.py in ?(self)
#    1306                     if lk is not None:
#    1307                         # Then we're either Hashable or a wrong-length arraylike,
#    1308                         #  the latter of which will raise
#    1309                         lk = cast(Hashable, lk)
# -> 1310                         left_keys.append(left._get_label_or_level_values(lk))
#    1311                         join_names.append(lk)
#    1312                     else:
#    1313                         # work-around for merge_asof(left_index=True)
#
# /usr/local/lib/python3.12/site-packages/pandas/core/generic.py in ?(self, key, axis)
#    1907             values = self.xs(key, axis=other_axes[0])._values
#    1908         elif self._is_level_reference(key, axis=axis):
#    1909             values = self.axes[axis].get_level_values(key)._values
#    1910         else:
# -> 1911             raise KeyError(key)
#    1912
#    1913         # Check for duplicates
#    1914         if values.ndim > 1:
#
# KeyError: 'tabkey'

# %%
df
